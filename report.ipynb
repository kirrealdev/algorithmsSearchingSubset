# %%
import numpy as np              
import matplotlib.pyplot as plt 
# %matplotlib inline 
import pandas as pd             
import seaborn as sns          
import sklearn

# %%
naive_time_test1_end = [0,0.001,0.003,0.001,0.003,0.005,0.005,0.003,0.007,0.008]
naive_length_test1_end = [20,30,73,48,102,133,148,92,180,226]
naive_time_test2_middle = [0,0.001,0.002,0.001,0.003,0.002,0.003,0.002,0.004,0.004]
naive_length_test2_middle = [20,30,75,50,104,135,150,91,179,228]

# %%
rk_time_test1_end = [0.001,0.001,0.002,0.001,0.002,0.002,0.005,0.003,0.005,0.005]
rk_length_test1_end = [20,30,73,48,102,133,148,92,180,226]
rk_time_test2_middle = [0,0,0.001,0.001,0.002,0.002,0.002,0.001,0.002,0.003]
rk_length_test2_middle = [20,30,75,50,104,135,150,91,179,228]

# %%
kmp_time_test1_end = [0,0,0.001,0.001,0.002,0.002,0.002,0.001,0.002,0.003]
kmp_length_test1_end = [20,30,73,48,102,133,148,92,180,226]
kmp_time_test2_middle = [0,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.002,0.002]
kmp_length_test2_middle = [20,30,75,50,104,135,150,91,179,228]

# %% [markdown]
# ## Эксперимент 1 (а)
#
# В качестве образца и строки выбираются подстроки некоторого текста ествественного языка. Длина образца равна ~ 1/4 длины текста.
# Длина суммы текста и образца изменяется от 20 до 226. Образец занимает фиксированную позицию в конце текста.
#
# Синим цветом отображены результаты наивного алгоритма.
# Красным цветов отображены результаты алгоритма Рабина-Карпа.
# Зеленым цветом отображены результаты алгоритма Кнута-Морриса-Пратта.

# %%
plt.scatter(naive_length_test1_end, naive_time_test1_end,color = 'blue')
plt.scatter(rk_length_test1_end, rk_time_test1_end,color = 'red')
plt.scatter(kmp_length_test1_end, kmp_time_test1_end,color = 'green')
plt.xlabel("length")
plt.ylabel("time")
plt.ylim(0, 0.009);

# %% [markdown]
# ## Эксперимент 2 (а)
#
# В качестве образца и строки выбираются подстроки некоторого текста ествественного языка. Длина образца равна ~ 1/4 длины текста.
# Длина суммы текста и образца изменяется от 20 до 228. Образец занимает фиксированную позицию в середине текста.
#
# Синим цветом отображены результаты наивного алгоритма.
# Красным цветов отображены результаты алгоритма Рабина-Карпа.
# Зеленым цветом отображены результаты алгоритма Кнута-Морриса-Пратта.

# %%
plt.scatter(naive_length_test2_middle, naive_time_test2_middle,color = 'blue')
plt.scatter(rk_length_test2_middle, rk_time_test2_middle,color = 'red')
plt.scatter(kmp_length_test2_middle, kmp_time_test2_middle,color = 'green')
plt.xlabel("length")
plt.ylabel("time")
plt.ylim(0, 0.005);

# %%
naive_time_test4_end = [0.001,0.001,0.002,0.002,0.002,0.002,0.003,0.003,0.003,0.004]
naive_length_test4_end = [20,30,40,50,60,70,80,90,100,110]
naive_time_test5_middle = [0.001,0.001,0.001,0.001,0.002,0.001,0.002,0.001,0.003,0.003]
naive_length_test5_middle = [20,30,40,50,60,70,80,90,100,110]

# %%
rk_time_test4_end = [0.001,0.001,0.001,0.001,0.002,0.003,0.003,0.003,0.003,0.003]
rk_length_test4_end = [20,30,40,50,60,70,80,90,100,110]
rk_time_test5_middle = [0,0,0.001,0,0.001,0.001,0.001,0.002,0.002,0.002]
rk_length_test5_middle = [20,30,40,50,60,70,80,90,100,110]

# %%
kmp_time_test4_end = [0,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.001,0.002]
kmp_length_test4_end = [20,30,40,50,60,70,80,90,100,110]
kmp_time_test5_middle = [0,0,0,0,0,0.001,0.001,0.001,0.001,0.002]
kmp_length_test5_middle = [20,30,40,50,60,70,80,90,100,110]

# %% [markdown]
# ## Эксперимент 1 (б)
#
# В качестве образца и строки выбираются случайные строки. Длина образца равна ~ 1/4 длины текста.
# Длина суммы текста и образца меняется от 20 до 110. Образец занимает фиксированную позицию в конце текста.
#
# Синим цветом отображены результаты наивного алгоритма.
# Красным цветов отображены результаты алгоритма Рабина-Карпа.
# Зеленым цветом отображены результаты алгоритма Кнута-Морриса-Пратта.

# %%
plt.scatter(naive_length_test4_end, naive_time_test4_end,color = 'blue')
plt.scatter(rk_length_test4_end, rk_time_test4_end,color = 'red')
plt.scatter(kmp_length_test4_end, kmp_time_test4_end,color = 'green')
plt.xlabel("length")
plt.ylabel("time")
plt.ylim(0, 0.005);

# %% [markdown]
# ## Эксперимент 2 (б)
#
# В качестве образца и строки выбираются случайные строки. Длина образца равна ~ 1/4 длины текста.
# Длина суммы текста и образца меняется от 20 до 110. Образец занимает фиксированную позицию в середине текста.
#
# Синим цветом отображены результаты наивного алгоритма.
# Красным цветов отображены результаты алгоритма Рабина-Карпа.
# Зеленым цветом отображены результаты алгоритма Кнута-Морриса-Пратта.

# %%
plt.scatter(naive_length_test5_middle, naive_time_test5_middle,color = 'blue')
plt.scatter(rk_length_test5_middle, rk_time_test5_middle,color = 'red')
plt.scatter(kmp_length_test5_middle, kmp_time_test5_middle,color = 'green')
plt.xlabel("length")
plt.ylabel("time")
plt.ylim(0, 0.005);

# %% [markdown]
# ## Выводы:
#
# По результатом экспериментов можно сделать вывод, что алгоритм Кнута-Морриса-Пратта работает быстрее чем наивный и Рабина-Карпа, независимо от того стоит ли образец в середине или в конце. Самым медленным оказался наивный алгоритм.
